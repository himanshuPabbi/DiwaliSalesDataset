# %% [markdown]
# # Project Title : Diwali Sales Dataset
# ## Quantitative
# ## A quantitative variable is a variable that reflects a notion of magnitude, that is, if the values it can take are numbers. A quantitative variable represents thus a measure and is numerical.
#
# ## Quantitative variables are divided into two types: discrete and continuous. The difference is explained in the following two sections.
#
# ## Discrete
# ## Quantitative discrete variables are variables for which the values it can take are countable and have a finite number of possibilities. The values are often (but not always) integers. Here are some examples of discrete variables:
#
# ## Continuous
# ## On the other hand, quantitative continuous variables are variables for which the values are not countable and have an infinite number of possibilities. For example: Age,Weight,Height
#
# ## Qualitative
# ## In opposition to quantitative variables, qualitative variables (also referred as categorical variables or factors in R) are variables that are not numerical and which values fits into categories.
#
# ## In other words, a qualitative variable is a variable which takes as its values modalities, categories or even levels, in contrast to quantitative variables which measure a quantity on each individual.
#
# ## Qualitative variables are divided into two types: nominal and ordinal.
# ## Nominal
# ## A qualitative nominal variable is a qualitative variable where no ordering is possible or implied in the levels.
#
# ## For example, the variable gender is nominal because there is no order in the levels (no matter how many levels you consider for the gender—only two with female/male, or more than two with female/male/ungendered/others, levels are unordered). Eye color is another example of a nominal variable because there is no order among blue, brown or green eyes.
#
# ## Ordinal
# ## On the other hand, a qualitative ordinal variable is a qualitative variable with an order implied in the levels. For instance, if the severity of road accidents has been measured on a scale such as light, moderate and fatal accidents, this variable is a qualitative ordinal variable because there is a clear order in the levels.
#
# ## Another good example is health, which can take values such as poor, reasonable, good, or excellent. Again, there is a clear order in these levels so health is in this case a qualitative ordinal variable
#
# ## Nominal :
# 1. Gender
# 2. State
# 3. Zone
# 4. Occupation
# 5. Product_Category
# 6. Customer Name
# 7. Product_ID
#
# ## Ordinal :None
#
# ## DISCRETE:
# 8. Marital_Status
# 9. Age
# 10. Orders
# 11. User_ID
# ## Continuous:
# 12. Amount
# 13. Age Group

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Diwali Sales Data.csv',encoding='latin1')

# %%
df #display the data frame
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.isnull().sum() #count the number of NaN in each column by calling sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.dtypes #check data type of each column using dtypes method
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# Status              float64
# unnamed1            float64
# dtype: object

# %%
df.shape #shape method is used to check number of rows and columns
# Out:
# (11251, 15)

# %%
df=df.drop(['Status','unnamed1','User_ID','Cust_name','Product_ID'],axis=1) #drop the columns which are not required

# %%
df #display the data frame
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 0          F     26-35   28               0     Maharashtra   Western
# 1          F     26-35   35               1  Andhra Pradesh  Southern
# 2          F     26-35   35               1   Uttar Pradesh   Central
# 3          M      0-17   16               0       Karnataka  Southern
# 4          M     26-35   28               1         Gujarat   Western
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#             Occupation Product_Category  Orders   Amount
# 0           Healthcare             Auto       1  23952.0
# ...

# %%
df.isnull().sum() ##count the number of NaN in each column by calling sum()
# Out:
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
sns.boxplot(df['Age'])
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Removing Outliers using IQR

# %%
q3=np.percentile(df['Age'],75)

# %%
q3
# Out:
# 43.0

# %%
q1=np.percentile(df['Age'],25)

# %%
q1
# Out:
# 27.0

# %%
IQR=q3-q1 #75%-25%

# %%
lower=q1-1.5*IQR

# %%
higher=q3+1.5*IQR

# %%
df=df[(df['Age']>lower) & (df['Age']<higher)]  #any value outside the range will be rejected

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 0          F     26-35   28               0     Maharashtra   Western
# 1          F     26-35   35               1  Andhra Pradesh  Southern
# 2          F     26-35   35               1   Uttar Pradesh   Central
# 3          M      0-17   16               0       Karnataka  Southern
# 4          M     26-35   28               1         Gujarat   Western
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#             Occupation Product_Category  Orders   Amount
# 0           Healthcare             Auto       1  23952.0
# ...

# %%
sns.boxplot(df['Age'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# # Creating a new feature Amount Range by dividing the amount feature into 4 equal size bins using qcut method of pandas

# %%
df['AmountRange']=pd.qcut(df['Amount'],4)
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_30768\4196590691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AmountRange']=pd.qcut(df['Amount'],4)

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 0          F     26-35   28               0     Maharashtra   Western
# 1          F     26-35   35               1  Andhra Pradesh  Southern
# 2          F     26-35   35               1   Uttar Pradesh   Central
# 3          M      0-17   16               0       Karnataka  Southern
# 4          M     26-35   28               1         Gujarat   Western
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#             Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %% [markdown]
# ## A Distplot or distribution plot, depicts the variation in the data distribution. Seaborn Distplot represents the overall distribution of continuous data variables

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['Amount'])
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Filling Missing values with Median amount value because graph is not normal distribution

# %%
median_val=df['Amount'].median()

# %%
median_val
# Out:
# 8109.0

# %%
df['Amount'].fillna(median_val,inplace=True) 
#Not a normal distribution so replace missing values by median
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_30768\482356986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Amount'].fillna(median_val,inplace=True)

# %%
df['Amount'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 0          F     26-35   28               0     Maharashtra   Western
# 1          F     26-35   35               1  Andhra Pradesh  Southern
# 2          F     26-35   35               1   Uttar Pradesh   Central
# 3          M      0-17   16               0       Karnataka  Southern
# 4          M     26-35   28               1         Gujarat   Western
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#             Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %% [markdown]
# # Removing Outliers using IQR

# %%
sns.boxplot(df['Amount'])
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
q3=np.percentile(df['Amount'],75)

# %%
q3
# Out:
# 12654.0

# %%
q1=np.percentile(df['Amount'],25)

# %%
q1
# Out:
# 5444.0

# %%
IQR=q3-q1

# %%
IQR
# Out:
# 7210.0

# %%
lower=q1-1.5*IQR

# %%
higher=q3+1.5*IQR

# %%
lower
# Out:
# -5371.0

# %%
higher
# Out:
# 23469.0

# %%
df=df[(df['Amount']>lower) & (df['Amount']<higher)]

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
sns.boxplot(df['Amount'])
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='Zone',data=df)
plt.show()

# %% [markdown]
# # From the above graph it is clear that
# 1. Maximum number of orders are from Central Zone
# 2. Minimum number of orders are from Eastern Zone

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='Zone',data=df,hue='Gender')
plt.show()

# %%
gender_df=df.groupby('Gender')

# %%
gender_df['Zone'].value_counts()
# Out:
# Gender  Zone
# F       Central     2883
#         Southern    1819
#         Western     1378
#         Northern    1010
#         Eastern      553
# M       Central     1284
#         Southern     798
#         Western      521
#         Northern     448
#         Eastern      242
# Name: Zone, dtype: int64

# %% [markdown]
# # From the above graph
# 1. It is clear that from Central Zone max number of females do orders
# 2. It is clear that from Eastern Zone min number of males do orders

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='Zone',data=df,hue='Orders')
plt.show()

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
zone_df=df.groupby('Zone')

# %%
zone_df['Orders'].value_counts()
# Out:
# Zone      Orders
# Central   2         1087
#           1         1060
#           4         1018
#           3         1002
# Eastern   2          208
#           3          201
#           1          198
#           4          188
# Northern  2          390
#           4          384
#           1          360
#           3          324
# Southern  2          677
#           3          660
#           4          642
#           1          638
# Western   3          493
#           1          481
#           4          471
#           2          454
# Name: Orders, dtype: int64

# %% [markdown]
# # From the above graph
# 1. It is clear that from Central Zone quantity of orders from 1 to 4 is max.
# 2. It is clear that from Eastern Zone quantity of orders from 1 to 4 is min.

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='Zone',data=df,hue='Marital_Status')
plt.show()

# %% [markdown]
# ## From the above graph
# 1. It is clear that from Central Zone unmarried and married males and females who do order are maximum
# 2. It is clear that from Eastern Zone unmarried and married males and females  who do order are minimum

# %%
plt.figure(figsize=(25,15))
sns.countplot(x='Zone',data=df,hue='Occupation')
plt.show()

# %%
zone_df=df.groupby('Zone')

# %%
zone_df['Occupation'].value_counts()
# Out:
# Zone     Occupation
# Central  IT Sector          617
#          Healthcare         513
#          Aviation           490
#          Banking            393
#          Govt               326
#                            ...
# Western  Retail              81
#          Construction        66
#          Food Processing     66
#          Textile             45
#          Agriculture         40
# Name: Occupation, Length: 75, dtype: int64

# %% [markdown]
# ## From the above analysis it is clear that
# 1. customers from Central Zone working in IT Sector,Health Sector,Aviation Sector and banking Sector do maximum orders

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Gender'])
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
gender_df=df.groupby('Gender')

# %%
gender_df.size()
# Out:
# Gender
# F    7643
# M    3293
# dtype: int64

# %% [markdown]
# ## From the above graph it is clear that females do more orders than male
# 1. Count of number of males are 3301 and
# 2. Count of number of females are 7656

# %%
gender_label=df['Gender'].value_counts().index

# %%
gender_val=df['Gender'].value_counts().values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=gender_val,labels=gender_label,data=df,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Females do more shopping than males

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='Gender',data=df,hue='Marital_Status')
plt.show()

# %%
gender_df=df.groupby('Gender')

# %%
gender_df['Marital_Status'].value_counts()
# Out:
# Gender  Marital_Status
# F       0                 4448
#         1                 3195
# M       0                 1883
#         1                 1410
# Name: Marital_Status, dtype: int64

# %% [markdown]
# ## From the above graph it is clear that
# 1. unmarried males and females place more orders in comparison with married males and females
# 2. Unmarried Males :1886
# 3.Unmarried Females : 4454

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='Occupation',data=df,hue='Marital_Status')
plt.xticks(rotation=90)
plt.show()

# %%
occ_df=df.groupby('Occupation')

# %%
occ_df['Marital_Status'].value_counts()
# Out:
# Occupation       Marital_Status
# Agriculture      0                 149
#                  1                 128
# Automobile       0                 300
#                  1                 254
# Aviation         0                 711
#                  1                 568
# Banking          0                 556
#                  1                 555
# Chemical         0                 295
#                  1                 237
# Construction     0                 281
#                  1                 121
# Food Processing  0                 221
#                  1                 184
# Govt             0                 472
#                  1                 358
# Healthcare       0                 980
#                  1                 386
# Hospitality      0                 352
#                  1                 338
# IT Sector        0                 840
#                  1                 695
# Lawyer           0                 263
# ...

# %% [markdown]
# ## From the above graph it is clear that
# 1. unmarried males and females from Healthcare occupation  do maximum order in comparison to other occupation
# 2. unmarried males and females from Healthcare occupation : 981
# 3. Also married males and females from Retail occupation  do minimum order in comparison to other occupation
# 4. married males and females from Retail occupation : 117

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Occupation'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
occ_df=df.groupby('Occupation')

# %%
occ_df.size()
# Out:
# Occupation
# Agriculture         277
# Automobile          554
# Aviation           1279
# Banking            1111
# Chemical            532
# Construction        402
# Food Processing     405
# Govt                830
# Healthcare         1366
# Hospitality         690
# IT Sector          1535
# Lawyer              515
# Media               613
# Retail              489
# Textile             338
# dtype: int64

# %% [markdown]
# ## From the above graph it is clear that
# 1. customers from IT Sector  do maximum number of orders and
# 2. customers from Agriculture Sector do minimum number of orders
# 3. customers from IT Sector : 1537
# 4. customers from Agriculture Sector : 277

# %%
chemical_df=df[df['Occupation']=='Chemical']

# %%
plt.figure(figsize=(20,15))
sns.countplot(x='Occupation',hue='Product_Category',data=chemical_df)
plt.xticks(rotation=90)
plt.show()

# %%
chemical_df=occ_df.get_group('Chemical')

# %%
chemical_df['Product_Category'].value_counts()
# Out:
# Food                     129
# Clothing & Apparel       114
# Electronics & Gadgets    103
# Footwear & Shoes          56
# Household items           28
# Furniture                 23
# Games & Toys              15
# Beauty                    13
# Pet Care                  10
# Sports Products            9
# Office                     8
# Books                      7
# Stationery                 5
# Tupperware                 4
# Decor                      4
# Veterinary                 4
# Name: Product_Category, dtype: int64

# %% [markdown]
# ## From the above graph it is clear that
# 1. Customers from Chemical Occupation has order following product max and min number of times
# 2. Food  product category have maximum orders which is 86
# 3. Tupperware,Decor and Veterinary product category have minimum orders which is 4

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Product_Category'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
Prod_cat_df=df.groupby('Product_Category')

# %%
Prod_cat_df.size()
# Out:
# Product_Category
# Auto                       75
# Beauty                    407
# Books                     101
# Clothing & Apparel       2586
# Decor                      92
# Electronics & Gadgets    2036
# Food                     2430
# Footwear & Shoes         1028
# Furniture                 343
# Games & Toys              373
# Hand & Power Tools         25
# Household items           515
# Office                    107
# Pet Care                  209
# Sports Products           348
# Stationery                110
# Tupperware                 71
# Veterinary                 80
# dtype: int64

# %% [markdown]
# ## From the above graph it is clear that
# 1. Clothing & Apparel  product category have maximum orders which is 2430
# 2. Hand&Power Tools product category have minimum orders which is 25

# %%
textile_df=df[df['Occupation']=='Textile']

# %%
plt.figure(figsize=(20,15))
sns.countplot(x='Occupation',hue='Product_Category',data=textile_df)
plt.xticks(rotation=90)
plt.show()

# %%
textile_df=df.groupby('Occupation').get_group('Textile')

# %%
textile_df['Product_Category'].value_counts()
# Out:
# Clothing & Apparel       86
# Electronics & Gadgets    81
# Food                     61
# Footwear & Shoes         29
# Household items          18
# Games & Toys             13
# Sports Products          13
# Beauty                   10
# Furniture                 8
# Pet Care                  7
# Office                    3
# Stationery                2
# Tupperware                2
# Books                     2
# Decor                     2
# Auto                      1
# Name: Product_Category, dtype: int64

# %% [markdown]
# ## From the above graph it is clear that
# 1. customers from Textile Occupation has order following product max and min number of times
# 2. Clothing & Apparel  product category have maximum orders which is 86
# 3. Auto product category have minimum orders which is 1

# %%
agriculture_df=df[df['Occupation']=='Agriculture']

# %%
plt.figure(figsize=(20,15))
sns.countplot(x='Occupation',hue='Product_Category',data=agriculture_df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='Product_Category',data=df,hue='Gender')
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
prod_cat_df=df.groupby('Product_Category')

# %%
prod_cat_df['Gender'].value_counts()
# Out:
# Product_Category       Gender
# Auto                   F           52
#                        M           23
# Beauty                 F          313
#                        M           94
# Books                  M           64
#                        F           37
# Clothing & Apparel     F         1800
#                        M          786
# Decor                  F           75
#                        M           17
# Electronics & Gadgets  F         1440
#                        M          596
# Food                   F         1726
#                        M          704
# Footwear & Shoes       F          786
#                        M          242
# Furniture              F          212
#                        M          131
# Games & Toys           F          268
#                        M          105
# Hand & Power Tools     M           16
#                        F            9
# Household items        F          282
#                        M          233
# ...

# %% [markdown]
# ## From the above graph it is clear that
# 1. Females and Males have done
# 2. Maximum order in clothing&Apparel product category
# 3. Total Order from Clothing & Apparel : By Females = 1800 and By Male = 786
# 4. Minimum order in hand&PowerTools product category
# 5. Total Order from Hand & Power Tools : By Females = 9 and By Male = 16

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['State'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_State=df.groupby('State')

# %%
df_State.size()
# Out:
# State
# Andhra Pradesh       782
# Bihar                421
# Delhi               1084
# Gujarat              414
# Haryana              441
# Himachal Pradesh     591
# Jharkhand            374
# Karnataka           1280
# Kerala               435
# Madhya Pradesh       896
# Maharashtra         1485
# Punjab               200
# Rajasthan            226
# Telangana            120
# Uttar Pradesh       1881
# Uttarakhand          306
# dtype: int64

# %% [markdown]
# ## From the above graph is it clear that
# 1. Maximum orders are from Uttar Pradesh
# 2. Orders from Uttar Pradesh : 1881
# 3. Minimum orders are from Telangana
# 4. Orders from Telangana : 120

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,x=df['State'],hue='Gender')
plt.xticks(rotation=90)
plt.show()

# %%
df_State=df.groupby('State')

# %%
df_State['Gender'].value_counts()
# Out:
# State             Gender
# Andhra Pradesh    F          535
#                   M          247
# Bihar             F          293
#                   M          128
# Delhi             F          738
#                   M          346
# Gujarat           F          295
#                   M          119
# Haryana           F          319
#                   M          122
# Himachal Pradesh  F          412
#                   M          179
# Jharkhand         F          260
#                   M          114
# Karnataka         F          904
#                   M          376
# Kerala            F          307
#                   M          128
# Madhya Pradesh    F          602
#                   M          294
# Maharashtra       F         1083
#                   M          402
# Punjab            F          134
#                   M           66
# Rajasthan         F          145
#                   M           81
# Telangana         F           73
# ...

# %% [markdown]
# ## From the above graph it is clear that
# 1. Males and Females customer from Uttar Pradesh have done maximum order
# 2. Orders from Uttar Pradesh :
# ### By Males : 547 and By Females : 1334
#
#
# 3. Males and Females customer from Telangana have done minimum order
# 4. Orders from Telangana :
# ### By Males : 47 and By Females :73

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,x=df['State'],hue='Marital_Status')
plt.xticks(rotation=90)
plt.show()

# %%
state_df=df.groupby('State')

# %%
state_df['Marital_Status'].value_counts()
# Out:
# State             Marital_Status
# Andhra Pradesh    0                  453
#                   1                  329
# Bihar             0                  237
#                   1                  184
# Delhi             0                  617
#                   1                  467
# Gujarat           0                  261
#                   1                  153
# Haryana           0                  261
#                   1                  180
# Himachal Pradesh  0                  347
#                   1                  244
# Jharkhand         0                  217
#                   1                  157
# Karnataka         0                  724
#                   1                  556
# Kerala            0                  245
#                   1                  190
# Madhya Pradesh    0                  511
#                   1                  385
# Maharashtra       0                  868
#                   1                  617
# ...

# %% [markdown]
# ## From the above graph it is clear that
# 1. Married and un-married males and females customer from Uttar Pradesh have done maximum order
# 2. Orders from Uttar Pradesh :
# ### By married males and females  : 1079
# ### By un-married males and females : 802
#
#
# 3. Married and unmarried males and females customer from Telangana have done minimum order
# 4. Orders from Telangana :
# ### By married males and females  : 69
# ### By un-married males and females : 51

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Age Group',y='Amount',data=df)
plt.show()

# %%
age_group_df=df.groupby('Age Group')

# %%
age_group_df['Amount'].mean()
# Out:
# Age Group
# 0-17     9070.308475
# 18-25    9136.712380
# 26-35    9348.601931
# 36-45    9697.866356
# 46-50    9347.621704
# 51-55    9899.932449
# 55+      9369.537313
# Name: Amount, dtype: float64

# %% [markdown]
# ## From the above graph is it clear that
# 1.  Age group of 51-55 has spend maximum avg amount of 9899.932449 out of other age group
# 2. Age group of 0-17 has spend minimum avg amount of 9070.308475 out of other age group

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Age Group',y='Amount',data=df,hue='Gender')
plt.show()

# %%
age_group_df=df.groupby(['Age Group','Gender'])

# %%
age_group_df['Amount'].mean()
# Out:
# Age Group  Gender
# 0-17       F          8897.586420
#            M          9280.691729
# 18-25      F          9052.669231
#            M          9327.054007
# 26-35      F          9444.847152
#            M          9100.582478
# 36-45      F          9825.606888
#            M          9411.401418
# 46-50      F          9703.877698
#            M          8496.769759
# 51-55      F          9710.311031
#            M         10279.862319
# 55+        F          8818.643678
#            M         10389.276596
# Name: Amount, dtype: float64

# %% [markdown]
# ## From the above graph is it clear that
# 1.  Male customers of age group 51-55 has spend maximum avg amount of 10279.862319 out of other male customers in  different age group
# 2. Female customers of age group 51-55 has spend minimum avg amount of 8818.643678 out of other female customers in  different age group

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Occupation',y='Age',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
occ_df=df.groupby('Occupation')

# %%
occ_df['Age'].mean()
# Out:
# Occupation
# Agriculture        33.981949
# Automobile         34.850181
# Aviation           34.116497
# Banking            34.484248
# Chemical           34.343985
# Construction       33.728856
# Food Processing    34.540741
# Govt               34.353012
# Healthcare         33.871889
# Hospitality        34.821739
# IT Sector          34.214332
# Lawyer             34.023301
# Media              34.128874
# Retail             34.239264
# Textile            34.020710
# Name: Age, dtype: float64

# %% [markdown]
# ## From the above graph it is clear that
# 1. Customers working in Construction Occupation has average age 33.684864 years which is minimum avg age in comparison with other customer of different occupation
# 2. Customers working in Hospitality Occupation has average age 34.877168 years which is maximum avg age in comparison with other customer of different occupation

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Occupation',y='Age',data=df,hue='Gender')
plt.xticks(rotation=90)
plt.show()

# %%
occ_gender_df=df.groupby(['Occupation','Gender'])

# %%
occ_gender_df['Age'].mean()
# Out:
# Occupation       Gender
# Agriculture      F         34.710000
#                  M         32.090909
# Automobile       F         35.113990
#                  M         34.244048
# Aviation         F         34.256018
#                  M         33.767123
# Banking          F         34.563817
#                  M         34.273026
# Chemical         F         34.046070
#                  M         35.018405
# Construction     F         33.668942
#                  M         33.889908
# Food Processing  F         34.827465
#                  M         33.867769
# Govt             F         33.779661
#                  M         35.762500
# Healthcare       F         34.054487
#                  M         33.474419
# Hospitality      F         34.510870
#                  M         35.443478
# IT Sector        F         34.339423
#                  M         33.951515
# Lawyer           F         33.817416
#                  M         34.484277
# ...

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %% [markdown]
# ## From the above graph it is clear that
# 1. Male customers working in Govt Occupation has average age 35.762500 years which is maximum avg age in comparison with other male customers of different occupation
# 2. Female Customers working in Textile Occupation has average age 34.868996 years which is maximum avg age in comparison with other female customers of different occupation

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='State',y='Age',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
state_df=df.groupby('State')

# %%
state_df['Age'].mean()
# Out:
# State
# Andhra Pradesh      34.590793
# Bihar               34.225653
# Delhi               34.687269
# Gujarat             34.871981
# Haryana             34.011338
# Himachal Pradesh    34.416244
# Jharkhand           34.946524
# Karnataka           34.487500
# Kerala              32.636782
# Madhya Pradesh      34.512277
# Maharashtra         33.367677
# Punjab              34.530000
# Rajasthan           33.438053
# Telangana           35.908333
# Uttar Pradesh       34.170654
# Uttarakhand         35.068627
# Name: Age, dtype: float64

# %% [markdown]
# ## From the above graph it is clear that
# 1. From telangana State, avg age of customers who order is 35.90 years which is max as compared to other States.
# 2. From maharashtra State, avg age of customers who order is 33.36 years which is min as compared to other states.

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='State',y='Age',data=df,hue='Gender')
plt.xticks(rotation=90)
plt.show()

# %%
state_df=df.groupby(['State','Gender'])

# %%
state_df['Age'].mean()
# Out:
# State             Gender
# Andhra Pradesh    F         34.381308
#                   M         35.044534
# Bihar             F         33.781570
#                   M         35.242188
# Delhi             F         35.000000
#                   M         34.020231
# Gujarat           F         34.698305
#                   M         35.302521
# Haryana           F         33.990596
#                   M         34.065574
# Himachal Pradesh  F         34.694175
#                   M         33.776536
# Jharkhand         F         35.303846
#                   M         34.131579
# Karnataka         F         34.414823
#                   M         34.662234
# Kerala            F         32.931596
#                   M         31.929688
# Madhya Pradesh    F         35.056478
#                   M         33.397959
# Maharashtra       F         33.402585
#                   M         33.273632
# Punjab            F         33.843284
#                   M         35.924242
# ...

# %% [markdown]
# ## From the above graph it is clear that
# 1. Male customers from Uttarakhand have maximum avg age of 36.154639 years among other male customers from different states
# 2. Female customers from Telangana have maximum avg age of 35.767123 years among other female customers from different states

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
pro_cat_df=df.groupby('Product_Category')

# %%
pro_cat_df['Amount'].sum()
# Out:
# Product_Category
# Auto                      1405116.00
# Beauty                    1894088.00
# Books                     1035046.00
# Clothing & Apparel       16100144.00
# Decor                      701864.00
# Electronics & Gadgets    15283625.00
# Food                     33086949.50
# Footwear & Shoes         15098844.45
# Furniture                 5272632.99
# Games & Toys              4185300.00
# Hand & Power Tools         391054.00
# Household items           1555515.00
# Office                      77196.00
# Pet Care                   473177.00
# Sports Products           3557205.00
# Stationery                1646258.50
# Tupperware                1138799.00
# Veterinary                 111629.00
# Name: Amount, dtype: float64

# %%
amt_label=pro_cat_df['Amount'].sum().index

# %%
val_label=pro_cat_df['Amount'].sum().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=val_label,labels=amt_label,data=pro_cat_df,autopct='%1.2f%%')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## From the above graph it is clear that sum of amount of all orders from Food Category is maximum and minimum from Office Category
# 1. Total amount of Orders from Food Category : 33086949.50
# 2. Total amount of Orders from Office Category : 77196.00

# %% [markdown]
# # Find total amount of orders from each Occupation

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
occ_df=df.groupby('Occupation')

# %%
occ_df['Amount'].sum()
# Out:
# Occupation
# Agriculture         2529513.00
# Automobile          5187926.00
# Aviation           12281271.00
# Banking            10522998.95
# Chemical            5191676.00
# Construction        3496750.00
# Food Processing     3879851.00
# Govt                8189489.00
# Healthcare         12632915.49
# Hospitality         6227929.00
# IT Sector          14298896.00
# Lawyer              4801835.00
# Media               6042351.00
# Retail              4626605.00
# Textile             3104437.00
# Name: Amount, dtype: float64

# %%
label_amt=occ_df['Amount'].sum().index

# %%
label_val=occ_df['Amount'].sum().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=label_val,labels=label_amt,data=occ_df,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# # From the above pie-chart it is clear that
# 1. Sum of amount of all orders is maximum from IT Sector which is 14346144 and
# 2. Sum of amount of all orders is minimum from Agriculture Sector which is 2529513

# %% [markdown]
# # Total amount of order from each State

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
prod_cat_df=df.groupby('Product_Category')

# %%
prod_cat_df['Amount'].sum()
# Out:
# Product_Category
# Auto                      1405116.00
# Beauty                    1894088.00
# Books                     1035046.00
# Clothing & Apparel       16100144.00
# Decor                      701864.00
# Electronics & Gadgets    15283625.00
# Food                     33086949.50
# Footwear & Shoes         15098844.45
# Furniture                 5272632.99
# Games & Toys              4185300.00
# Hand & Power Tools         391054.00
# Household items           1555515.00
# Office                      77196.00
# Pet Care                   473177.00
# Sports Products           3557205.00
# Stationery                1646258.50
# Tupperware                1138799.00
# Veterinary                 111629.00
# Name: Amount, dtype: float64

# %%
label_amt=prod_cat_df['Amount'].sum().index

# %%
label_val=prod_cat_df['Amount'].sum().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=label_val,labels=label_amt,data=prod_cat_df,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# # From the above pie-chart it is clear that
# 1. Sum of amount of all orders is maximum from Food Category which is 33086949.50 and
# 2. Sum of amount of all orders is minimum from Office Category which is 77196.00

# %%
state_df=df.groupby('State')

# %%
state_df['Amount'].sum()
# Out:
# State
# Andhra Pradesh       7626776.00
# Bihar                3930216.00
# Delhi               11403897.45
# Gujarat              3784117.00
# Haryana              4105667.00
# Himachal Pradesh     4809645.00
# Jharkhand            2991552.00
# Karnataka           13193998.00
# Kerala               3747035.99
# Madhya Pradesh       7867517.00
# Maharashtra         13999557.00
# Punjab               1525800.00
# Rajasthan            1870963.00
# Telangana            1117580.00
# Uttar Pradesh       18657356.00
# Uttarakhand          2382766.00
# Name: Amount, dtype: float64

# %%
label_amt=state_df['Amount'].sum().index

# %%
label_val=state_df['Amount'].sum().values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=label_val,labels=label_amt,data=state_df,autopct='%1.2f%%')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above pie-chart it is clear that
# 1. Sum of amount of all orders is maximum from Uttar Pradesh State which is 18823106.00 and
# 2. Sum of amount of all orders is minimum from Telangana State which is 1117580.00

# %%
zone_label=df['Zone'].value_counts().index

# %%
zone_val=df['Zone'].value_counts().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=zone_val,labels=zone_label,data=df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # From the above pie-chart it is clear that
# # maximum order percentage is 38.10% from central zone
# # minimum order percentage is 7.27% from Eastern zone

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
age_df=df.groupby('Age Group')

# %%
df_0_17=age_df.get_group('0-17')

# %%
product_cat_label=df_0_17['Product_Category'].value_counts().index

# %%
product_cat_val=df_0_17['Product_Category'].value_counts().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=product_cat_val,labels=product_cat_label,data=df_0_17,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above analysis it is clear that Top 3 Category of products for Age range of 0-17 are:
# 1. Food
# 2. Clothing & Apparel
# 3. Electronics & Gadgets

# %%
df_55_plus=age_df.get_group('55+')

# %%
product_cat_label=df_55_plus['Product_Category'].value_counts().index

# %%
product_cat_val=df_55_plus['Product_Category'].value_counts().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=product_cat_val,labels=product_cat_label,data=df_55_plus,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above analysis it is clear that Top 3 Category of products for Age range of 55+ are:
# 1. Food
# 2. Clothing & Apparel
# 3. Electronics & Gadgets

# %%
# From the above analysis it is clear that Top 3 Category of products for Age range of 18-25 are:
## 1. Food
## 2. Clothing & Apparel
## 3. Electronics & Gadgets

# %%
df_18_25=age_df.get_group('18-25')

# %%
product_cat_label=df_18_25['Product_Category'].value_counts().index

# %%
product_cat_val=df_18_25['Product_Category'].value_counts().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=product_cat_val,labels=product_cat_label,data=df_18_25,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above analysis it is clear that Top 3 Category of products for Age range of 18-25 are:
# 1. Food
# 2. Clothing & Apparel
# 3. Electronics & Gadgets

# %%
df_26_35=age_df.get_group('26-35')

# %%
product_cat_label=df_26_35['Product_Category'].value_counts().index

# %%
product_cat_val=df_26_35['Product_Category'].value_counts().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=product_cat_val,labels=product_cat_label,data=df_26_35,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above analysis it is clear that Top 3 Category of products for Age range of 26-35 are:
# 1. Clothing & Apparel
# 2. Food
# 3. Electronics & Gadgets

# %%
df_36_45=age_df.get_group('36-45')

# %%
product_cat_label=df_36_45['Product_Category'].value_counts().index

# %%
product_cat_val=df_36_45['Product_Category'].value_counts().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=product_cat_val,labels=product_cat_label,data=df_36_45,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above analysis it is clear that Top 3 Category of products for Age range of 36-45 are:
# 1. Clothing & Apparel
# 2. Food
# 3. Electronics & Gadgets

# %%
df_46_50=age_df.get_group('46-50')

# %%
product_cat_label=df_46_50['Product_Category'].value_counts().index

# %%
product_cat_val=df_46_50['Product_Category'].value_counts().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=product_cat_val,labels=product_cat_label,data=df_46_50,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above analysis it is clear that Top 3 Category of products for Age range of 46-50 are:
# 1. Clothing & Apparel
# 2. Food
# 3. Electronics & Gadgets

# %%
#Age Group and Occupation

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
occu_df=df.groupby('Occupation')

# %%
it_sector_df=occu_df.get_group('IT Sector')

# %%
it_sector_df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 49         F     51-55   53               0  Andhra Pradesh  Southern
# 50         F     36-45   43               1  Andhra Pradesh  Southern
# ...      ...       ...  ...             ...             ...       ...
# 11203      M     46-50   49               1     Maharashtra   Western
# 11216      M     46-50   48               0         Gujarat   Western
# 11220      F     26-35   30               1           Delhi   Central
# 11238      M     26-35   28               0       Karnataka  Southern
# 11240      F      0-17   12               0           Delhi   Central
#
#       Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
it_sector_df['Product_Category'].value_counts()
# Out:
# Clothing & Apparel       344
# Food                     333
# Electronics & Gadgets    283
# Footwear & Shoes         154
# Household items           92
# Beauty                    71
# Games & Toys              55
# Furniture                 39
# Sports Products           36
# Pet Care                  26
# Office                    18
# Books                     15
# Decor                     15
# Stationery                13
# Veterinary                13
# Tupperware                11
# Auto                      11
# Hand & Power Tools         6
# Name: Product_Category, dtype: int64

# %%
prod_label_df=it_sector_df['Product_Category'].value_counts().index

# %%
prod_val_df=it_sector_df['Product_Category'].value_counts().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=prod_val_df,labels=prod_label_df,data=it_sector_df,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above analysis it is clear that Top 3 Product Category for IT Sector
# 1. Clothing & Apparel
# 2. Food
# 3. Electronics & Gadgets

# %%
hospitality_sector_df=occu_df.get_group('Hospitality')

# %%
prod_label_df=hospitality_sector_df['Product_Category'].value_counts().index

# %%
prod_val_df=hospitality_sector_df['Product_Category'].value_counts().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=prod_val_df,labels=prod_label_df,data=hospitality_sector_df,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above analysis it is clear that Top 3 Category of products for Age range of 46-50 are:
# 1. Clothing & Apparel
# 2. Electronics & Gadgets
# 3. Food

# %%
banking_sector_df=occu_df.get_group('Banking')

# %%
prod_label_df=banking_sector_df['Product_Category'].value_counts().index

# %%
prod_val_df=banking_sector_df['Product_Category'].value_counts().values

# %%
plt.figure(figsize=(10,15))
plt.pie(x=prod_val_df,labels=prod_label_df,data=banking_sector_df,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above analysis it is clear that top 3 category of products for age range of 46-50 are:
# 1. Clothing & Apparel
# 2. Electronics & Gadgets
# 3. Food

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
label_married_df=df['Marital_Status'].value_counts().index

# %%
label_married_val_df=df['Marital_Status'].value_counts().values

# %%
exp=[0,0.3]

# %%
c=['r','b','g','y']

# %%
plt.figure(figsize=(5,10))
plt.pie(x=label_married_val_df,explode=exp,labels=label_married_df,shadow=True,colors=c,data=df,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above pie chart it is clear that
# 1. un-married customers place more orders compare to married customers.

# %%
df
# Out:
#       Gender Age Group  Age  Marital_Status           State      Zone  \
# 7          F       55+   61               0     Maharashtra   Western
# 14         M     46-50   46               1  Madhya Pradesh   Central
# 16         F     46-50   48               1  Andhra Pradesh  Southern
# 25         F     26-35   33               0  Andhra Pradesh  Southern
# 26         F     36-45   40               0   Uttar Pradesh   Central
# ...      ...       ...  ...             ...             ...       ...
# 11246      M     18-25   19               1     Maharashtra   Western
# 11247      M     26-35   33               0         Haryana  Northern
# 11248      F     36-45   40               0  Madhya Pradesh   Central
# 11249      M     36-45   37               0       Karnataka  Southern
# 11250      F     18-25   19               0     Maharashtra   Western
#
#         Occupation Product_Category  Orders   Amount         AmountRange
# ...

# %%
df['Occupation'].value_counts()
# Out:
# IT Sector          1535
# Healthcare         1366
# Aviation           1279
# Banking            1111
# Govt                830
# Hospitality         690
# Media               613
# Automobile          554
# Chemical            532
# Lawyer              515
# Retail              489
# Food Processing     405
# Construction        402
# Textile             338
# Agriculture         277
# Name: Occupation, dtype: int64

# %%
Occupation_label_df=df['Occupation'].value_counts().index

# %%
Occupation_val_df=df['Occupation'].value_counts().values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=Occupation_val_df,labels=Occupation_label_df,data=df,shadow=True,autopct="%1.2f%%")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # From the above pie chart it is clear that
# 1. maximum orders are given by customers working in  IT Sector
# 2. mininum orders are given by customers working in Agriculture Sector
